# %%
import random

# %%
words = []
letter="a"
position=1 #a is first letter 
wordlist=[]
with open('words.txt') as w:
  words = w.readlines() #returns a list containing each line in the file as a list item

while letter!='':
  del wordlist[:]
  letter=input("What letter do you know? ")
  color=input("What color is it? (Y,G,B): ")
  if color == 'g' or color == 'G' or color == 'y' or color == 'Y':
    position=int(input("What position is it? (1-5)"))-1
  for word in words:
    if color == 'g' or color == 'G':
      if word[position]==letter:
        wordlist.append(word)
    elif color == 'b' or color == 'B':
      if letter not in word:
        wordlist.append(word)
    elif color == 'y' or color == 'Y':
      if letter in word:
        if word[position]!=letter:
          wordlist.append(word)
  words=wordlist.copy()
  print(*wordlist)
# Out:
# What letter do you know? t
# What color is it? (Y,G,B): g
# What position is it? (1-5)4
# write
#  earth
#  parts
#  white
#  state
#  quite
#  wrote
#  party
#  mouth
#  north
#  death
#  south
#  teeth
#  facts
#  forth
#  units
#  month
#  wants
#  cents
#  empty
#  roots
#  cloth
#  worth
#  boats
#  fifty
#  truth
#  plate
#  taste
#  costs
#  youth
#  faith
#  tests
#  waste
#  depth
#  spite
#  fifth
#  birth
#  width
#  route
#  forty
#  beats
#  boots
#  spots
#  seats
#  dirty
#  gifts
#  lists
#  sixty
#  coats
#  sixth
#  suits
#  unity
#  nests
#  goats
#  shots
#  tooth
#  poets
#  paste
#  sorts
#  tenth
#  dusty
#  tents
#  posts
#  wrath
#  belts
#  hosts
#  ports
#  pants
#  flute
#  melts
#  rests
#  haste
#  knots
#  ninth
#  meats
#  rusty
#  salty
#  acute
#  photo
#  flats
#  pints
#  debts
#  lifts
#  masts
#  beets
#  fists
#  carts
#  lasts
#  bolts
#  suite
#  lofty
#  quote
#  fonts
#  unite
#  booth
#  darts
#  forts
#  waltz
#  heats
#  colts
#  skate
#  meets
#  hints
#  waits
#  smote
#  tasty
#  texts
#  casts
#  plots
#  aunts
#  hurts
#  hunts
#  mists
#  nasty
#  delta
#  rents
#  slits
#  slate
#  misty
#  pests
#  kitty
#  crate
#  broth
#  motto
#  slots
#  sloth
#  caste
#  pelts
#  diets
#  riots
#  ducts
#  feats
#  salts
#  chute
#  gusts
#  quota
#  rafts
#  pinto
#  volts
#  brute
#  petty
#  exits
#  berth
#  hasty
#  mirth
#  booty
#  witty
#  tufts
#  piety
#  gnats
#  bouts
#  shuts
#  putty
#  filth
#  musty
#  tarts
#  halts
#  lusty
#  smith
#  molts
#  sects
#  tints
#  grate
#  girth
#  tilts
#  omits
#  loath
#  slats
#  warts
#  watts
#  hefty
#  butts
#  heath
#  aorta
#  knits
#  spits
#  firth
#  trots
#  grits
#  deity
#  baste
#  gusty
#  jetty
#  vents
#  froth
#  smite
#  toots
#  rusts
#  clots
#  dents
#  butte
#  duets
#  meaty
#  mints
#  felts
#  blots
#  emits
#  agate
#  hoots
#  ditty
#  frets
#  fasts
#  vista
#  skits
#  quits
#  welts
#  busts
#  irate
#  pacts
#  dusts
#  trite
#  jests
#  patty
#  runts
#  brats
#  silts
#  sifts
#  jolts
#  blitz
#  kilts
#  wilts
#  cysts
#  mitts
#  spats
#  abate
#  edits
#  moats
#  vests
#  lefts
#  chats
#  dolts
#  pasta
#  rifts
#  malts
#  baits
#  routs
#  musts
#  punts
#  marts
#  zests
#  flits
#  whits
#  gluts
#  bests
#  dints
#  pouts
#  lilts
#  mutts
#  nifty
#  loots
#  hilts
#  gists
#  gilts
#  wafts
#  soots
#  hefts
#  ousts
#  suets
#  lints
#  swats
#  putts
#  whets
#  gaits
#  dirts
#  newts
#  bunts
#  lofts
#  gotta
#  fatty
#  cacti
#  elite
#  junta
#  warty
#  quoth
#  cults
#  saith
#  facto
#  forte
#  sooty
#  gusto
#  wanta
#  hertz
#  sorta
#  nutty
#  gents
#  swath
#  spate
#  theta
#  amity
#  canto
#  dotty
#  laity
#  writs
#  saute
#  natty
#  lusts
#  goeth
#  troth
#  testy
#  abets
#  pasty
#  ratty
#  coati
#  runty
#  louts
#  peaty
#  cotta
#  dicta
#  coots
#  abuts
#  harts
#  tufty
#  purty
#  ditto
#  septa
#  bitty
#  lefty
#  frats
#  silty
#  neato
#  softy
#  potty
#  ikats
#  pesto
#  snits
#  gouty
#  fiats
#  panty
#  sooth
#  twits
#  girts
#  emote
#  rutty
#  torts
#  catty
#  glitz
#  matte
#  recto
#  rants
#  prate
#  linty
#  zesty
#  busty
#  chits
#  mufti
#  lotto
#  blats
#  stats
#  umpty
#  touts
#  sluts
#  obits
#  torte
#  jilts
#  klutz
#  batty
#  suety
#  hafta
#  elate
#  snots
#  manta
#  lotta
#  outta
#  teats
#  thats
#  fusty
#  carte
#  haute
#  molto
#  dieth
#  morts
#  plats
#  tilth
#  lento
#  spitz
#  grata
#  juste
#  orate
#  musta
#  neath
#  tutti
#  pruta
#  foots
#  shute
#  costa
#  dictu
#  wroth
#  lepta
#  rooty
#  softs
#  tacts
#  poste
#  ovate
#  smuts
#  yurts
#  ioctl
#  cento
#  rente
#  zloty
#  wonts
#  yenta
#  hafts
#  titty
#  shits
#  bents
#  stets
#  seeth
#  monte
#  pieta
#  kilty
#  recta
#  mosts
#  ghoti
#  fisty
#  wefts
#  unate
#  totty
#  gouts
#  crits
#  scats
#  sputa
#  oweth
#  couth
#  cunts
#  tatty
#  wists
#  prats
#  bahts
#  nitty
#  lieth
#  cants
#  farts
#  nerts
#  lilty
#  arity
#  gutty
#  whats
#  gutta
#  worts
#  malty
#  easts
#  doeth
#  twats
#  wests
#  peats
#  moots
#  pasts
